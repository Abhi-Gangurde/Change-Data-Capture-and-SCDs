# %% [markdown]
# # Initializaton

# %%
from pyspark.sql.functions import lit

# %% [markdown]
# ### Existing Dimension

# %%
dim_df = spark.createDataFrame(
    [
        [1, "Ravi", "Mumbai"],
        [2, "Anil", "Delhi"]
    ],
    ["customer_id", "customer_name", "city"]
)

# %%
dim_df.show()

# %% [markdown]
# ### New incomming dat

# %%
update_df = spark.createDataFrame([
                                  (1,"Ravi","Pune")
                                  ],
                                  ["customer_id","customer_name","city"]

                                  )

# %%
update_df.show()

# %%
# Type 0: Ignore update
final_df = dim_df
final_df.show()
